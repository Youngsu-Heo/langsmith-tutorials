# %% [markdown]
# 참고: https://pypi.org/project/langsmith/

# %%
from openai import OpenAI
from langsmith import wrappers, Client
from langsmith.wrappers import wrap_openai
from langchain_core.runnables import chain
from dotenv import load_dotenv
from os import environ as env

# %%
load_dotenv('.env-leo', override=True)
langsmith_key = env.get('LANGSMITH_API_KEY')
openai_api_key = env.get('OPENAI_API_KEY')

# %%
client = wrappers.wrap_openai(OpenAI(api_key=openai_api_key))

# %%
client.chat.completions.create(
    model="gpt-4-0125-preview",
    messages=[{"role": "user", "content": "Say this is a test"}],
)
# Out:
# ChatCompletion(id='chatcmpl-95y2omiATR089L01mKiYBk8dHrwz8', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='This is a test.', role='assistant', function_call=None, tool_calls=None))], created=1711209478, model='gpt-4-0125-preview', object='chat.completion', system_fingerprint='fp_a7daf7c51e', usage=CompletionUsage(completion_tokens=5, prompt_tokens=12, total_tokens=17))

# %% [markdown]
# 실행 결과
# ![image.png](attachment:image.png)
